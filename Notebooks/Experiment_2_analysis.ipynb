# %%
import pandas as pd
import plotly.graph_objects as go
from nixtlats import TimeGPT
import pandas as pd
from datetime import timedelta


def load_data(filename,x_column,y_column):
    df = filename
    df.index = pd.to_datetime(df[x_column])
    df.drop(columns=x_column,inplace=True)
    df[y_column] = df[y_column].astype(float)
    df['power'].resample('D').mean()
    return df

# %%
lol = pd.read_csv('EXP_2.csv', parse_dates=['time'],  usecols=['time', 'power'])
lol['time'] = pd.to_datetime(lol['time'])
lol['time'] = lol['time'] + timedelta(hours=6)

lol.head()
# Out:
#                  time  power
# 0 2024-01-08 13:21:47      0
# 1 2024-01-08 13:21:53     13
# 2 2024-01-08 13:21:58     13
# 3 2024-01-08 13:22:03     11
# 4 2024-01-08 13:22:08     12

# %%
lol2 = pd.read_csv('EXP_2v2.csv', parse_dates=['time'],  usecols=['time', 'power'])
lol2['time'] = pd.to_datetime(lol2['time'])
# lol2['time'] = lol2['time'] + timedelta(hours=6)

lol2.head()
# Out:
#                  time  power
# 0 2024-01-11 07:05:14      9
# 1 2024-01-11 07:05:30      8
# 2 2024-01-11 07:05:41      9
# 3 2024-01-11 07:05:46      8
# 4 2024-01-11 07:05:51     10

# %%
timegpt.plot(lol2, time_col='time', target_col='power')

# %%
timegpt = TimeGPT(
    # defaults to os.environ.get("TIMEGPT_TOKEN")
    token = ''
)

# %%
timegpt.plot(lol, time_col='time', target_col='power')

# %%
import pandas as pd

df = pd.read_csv('TestOffice2024_FanSpeedPower.csv', dtype={'time': str},usecols=['time', 'power','speed_act','speed_set'])

df['time'] = pd.to_datetime(df['time'].astype(str).str[:10], unit='s')
df['time'] = df['time'] + timedelta(hours=6)

df.head()
# Out:
#                  time  power  speed_act  speed_set
# 0 2024-01-08 11:16:29      0          0         10
# 1 2024-01-08 11:16:40     12        616        616
# 2 2024-01-08 11:16:46     13        616        616
# 3 2024-01-08 11:16:56     11        616        616
# 4 2024-01-08 11:17:01     13        616        616

# %%
start_time = '2024-01-08 13:20'
end_time = '2024-01-08 13:25'

filtered_df = df[(df['time'] >= start_time) & (df['time'] <= end_time)]

mean_power = filtered_df['power'].mean()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
# Out:
# The mean power between 2024-01-08 13:20 and 2024-01-08 13:25 is: 340.3863636363636

# %%
lol.head()
# Out:
#                  time  power
# 0 2024-01-08 13:21:47      0
# 1 2024-01-08 13:21:53     13
# 2 2024-01-08 13:21:58     13
# 3 2024-01-08 13:22:03     11
# 4 2024-01-08 13:22:08     12

# %% [markdown]
# ## ACTUAL TEST

# %%
lol = pd.read_csv('EXP_2.csv', parse_dates=['time'],  usecols=['time', 'power'])
lol['time'] = pd.to_datetime(lol['time'])

lol.head()
# Out:
#                  time  power
# 0 2024-01-08 07:21:47      0
# 1 2024-01-08 07:21:53     13
# 2 2024-01-08 07:21:58     13
# 3 2024-01-08 07:22:03     11
# 4 2024-01-08 07:22:08     12

# %%
start_time = '2024-01-08 07:21:53'
end_time = '2024-01-08 07:25:13'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-08 07:25:35'
end_time2 = '2024-01-08 07:30:25'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-08 07:30:36'
end_time3 = '2024-01-08 07:36:09'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-08 07:36:19'
end_time4 = '2024-01-08 07:40:33'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-08 07:40:54'
end_time5 = '2024-01-08 07:45:02'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-08 07:21:53 and 2024-01-08 07:25:13 is: 11.11111111111111
# The mean power between 2024-01-08 07:25:35 and 2024-01-08 07:30:25 is: 42.0
# The mean power between 2024-01-08 07:30:36 and 2024-01-08 07:36:09 is: 104.41666666666667
# The mean power between 2024-01-08 07:36:19 and 2024-01-08 07:40:33 is: 208.59375
# The mean power between 2024-01-08 07:40:54 and 2024-01-08 07:45:02 is: 366.55
# Standard deviation of 'power': 0.8915558282417287
# Standard deviation of 'power': 0.7878385971583354
# Standard deviation of 'power': 0.7319250547113999
# Standard deviation of 'power': 1.1030566037007086
# Standard deviation of 'power': 3.037796097206843

# %%
start_time = '2024-01-08 08:01:16,12'
end_time = '2024-01-08 08:05:24'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-08 08:05:40'
end_time2 = '2024-01-08 08:11:18'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-08 08:11:29'
end_time3 = '2024-01-08 08:15:37'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-08 08:15:48'
end_time4 = '2024-01-08 08:21:05'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-08 08:21:15'
end_time5 = '2024-01-08 08:25:45'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-08 08:01:16,12 and 2024-01-08 08:05:24 is: 11.884615384615385
# The mean power between 2024-01-08 08:05:40 and 2024-01-08 08:11:18 is: 42.96666666666667
# The mean power between 2024-01-08 08:11:29 and 2024-01-08 08:15:37 is: 105.43333333333334
# The mean power between 2024-01-08 08:15:48 and 2024-01-08 08:21:05 is: 209.07692307692307
# The mean power between 2024-01-08 08:21:15 and 2024-01-08 08:25:45 is: 365.04545454545456
# Standard deviation of 'power': 0.8161824833662178
# Standard deviation of 'power': 0.7648904962570576
# Standard deviation of 'power': 0.6789105539243627
# Standard deviation of 'power': 1.493575987611354
# Standard deviation of 'power': 3.2845979220467365

# %%
# No filter
start_time = '2024-01-08 09:20:34'
end_time = '2024-01-08 09:25:56'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-08 09:26:12'
end_time2 = '2024-01-08 09:31:34'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-08 09:31:56'
end_time3 = '2024-01-08 09:35:27'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-08 09:35:43'
end_time4 = '2024-01-08 09:40:34'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-08 09:40:44'
end_time5 = '2024-01-08 09:45:03'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-08 09:20:34 and 2024-01-08 09:25:56 is: 11.194444444444445
# The mean power between 2024-01-08 09:26:12 and 2024-01-08 09:31:34 is: 38.1875
# The mean power between 2024-01-08 09:31:56 and 2024-01-08 09:35:27 is: 90.58333333333333
# The mean power between 2024-01-08 09:35:43 and 2024-01-08 09:40:34 is: 177.11111111111111
# The mean power between 2024-01-08 09:40:44 and 2024-01-08 09:45:03 is: 310.93023255813955
# Standard deviation of 'power': 0.7099072150416942
# Standard deviation of 'power': 0.8590129369261278
# Standard deviation of 'power': 0.7172815023567723
# Standard deviation of 'power': 1.7853015396009682
# Standard deviation of 'power': 2.613111161934948

# %%
# 25% Block
start_time = '2024-01-08 10:35:33'
end_time = '2024-01-08 10:40:29'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-08 10:40:34'
end_time2 = '2024-01-08 10:44:53'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-08 10:45:09'
end_time3 = '2024-01-08 10:50:26'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-08 10:50:37'
end_time4 = '2024-01-08 10:55:33'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-08 10:55:49'
end_time5 = '2024-01-08 11:00:18'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-08 10:35:33 and 2024-01-08 10:40:29 is: 11.208333333333334
# The mean power between 2024-01-08 10:40:34 and 2024-01-08 10:44:53 is: 42.53846153846154
# The mean power between 2024-01-08 10:45:09 and 2024-01-08 10:50:26 is: 105.73684210526316
# The mean power between 2024-01-08 10:50:37 and 2024-01-08 10:55:33 is: 209.4047619047619
# The mean power between 2024-01-08 10:55:49 and 2024-01-08 11:00:18 is: 368.5581395348837
# Standard deviation of 'power': 0.7790276362049131
# Standard deviation of 'power': 0.7060180864974624
# Standard deviation of 'power': 0.7947194142390265
# Standard deviation of 'power': 1.5469801236291307
# Standard deviation of 'power': 2.6574452964973654

# %%
# 50% Block
start_time = '2024-01-09 01:45:18'
end_time = '2024-01-09 02:02:45'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-09 02:02:55'
end_time2 = '2024-01-09 02:13:03'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-09 02:13:14'
end_time3 = '2024-01-09 02:20:48'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-09 02:21:20'
end_time4 = '2024-01-09 02:26:11'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-09 02:26:16'
end_time5 = '2024-01-09 02:30:51'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-09 01:45:18 and 2024-01-09 02:02:45 is: 11.404255319148936
# The mean power between 2024-01-09 02:02:55 and 2024-01-09 02:13:03 is: 41.68421052631579
# The mean power between 2024-01-09 02:13:14 and 2024-01-09 02:20:48 is: 104.23404255319149
# The mean power between 2024-01-09 02:21:20 and 2024-01-09 02:26:11 is: 209.25581395348837
# The mean power between 2024-01-09 02:26:16 and 2024-01-09 02:30:51 is: 370.14285714285717
# Standard deviation of 'power': 0.6610377786964038
# Standard deviation of 'power': 0.6855106213838522
# Standard deviation of 'power': 0.8395849377609622
# Standard deviation of 'power': 1.4157788241276543
# Standard deviation of 'power': 3.3609771268764623

# %%
# 75% Block
start_time = '2024-01-09 03:00:18'
end_time = '2024-01-09 03:07:30'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-09 03:07:52'
end_time2 = '2024-01-09 03:14:17'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-09 03:15:37'
end_time3 = '2024-01-09 03:20:12'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-09 03:20:28'
end_time4 = '2024-01-09 03:27:36'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-09 03:27:46'
end_time5 = '2024-01-09 03:32:48'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-09 03:00:18 and 2024-01-09 03:07:30 is: 10.796296296296296
# The mean power between 2024-01-09 03:07:52 and 2024-01-09 03:14:17 is: 39.888888888888886
# The mean power between 2024-01-09 03:15:37 and 2024-01-09 03:20:12 is: 101.06060606060606
# The mean power between 2024-01-09 03:20:28 and 2024-01-09 03:27:36 is: 204.08064516129033
# The mean power between 2024-01-09 03:27:46 and 2024-01-09 03:32:48 is: 365.8510638297872
# Standard deviation of 'power': 0.8098364528492048
# Standard deviation of 'power': 0.6979824404521128
# Standard deviation of 'power': 0.8268688657895648
# Standard deviation of 'power': 1.6124351515416127
# Standard deviation of 'power': 2.835939560619965

# %%
#95% blocked

# 75% Block
start_time = '2024-01-09 03:43:01'
end_time = '2024-01-09 03:48:55'
filtered_df = lol[(lol['time'] >= start_time) & (lol['time'] <= end_time)]

start_time2 = '2024-01-09 03:49:11'
end_time2 = '2024-01-09 03:55:21'
filtered_df2 = lol[(lol['time'] >= start_time2) & (lol['time'] <= end_time2)]

start_time3 = '2024-01-09 03:55:37'
end_time3 = '2024-01-09 04:00:07'
filtered_df3 = lol[(lol['time'] >= start_time3) & (lol['time'] <= end_time3)]

start_time4 = '2024-01-09 04:00:23'
end_time4 = '2024-01-09 04:05:40'
filtered_df4 = lol[(lol['time'] >= start_time4) & (lol['time'] <= end_time4)]

start_time5 = '2024-01-09 04:05:56'
end_time5 = '2024-01-09 04:11:24'
filtered_df5 = lol[(lol['time'] >= start_time5) & (lol['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-09 03:43:01 and 2024-01-09 03:48:55 is: 8.0
# The mean power between 2024-01-09 03:49:11 and 2024-01-09 03:55:21 is: 24.48
# The mean power between 2024-01-09 03:55:37 and 2024-01-09 04:00:07 is: 54.714285714285715
# The mean power between 2024-01-09 04:00:23 and 2024-01-09 04:05:40 is: 103.83333333333333
# The mean power between 2024-01-09 04:05:56 and 2024-01-09 04:11:24 is: 175.54
# Standard deviation of 'power': 0.7844645405527362
# Standard deviation of 'power': 0.6531972647421808
# Standard deviation of 'power': 0.8934871726729446
# Standard deviation of 'power': 1.4636517423090194
# Standard deviation of 'power': 3.0852512880159506

# %% [markdown]
# # Exp_v2

# %%
#51cm is about 57.95%

start_time = '2024-01-11 10:18:07'
end_time = '2024-01-11 10:23:08'
filtered_df = lol2[(lol2['time'] >= start_time) & (lol2['time'] <= end_time)]

start_time2 = '2024-01-11 10:23:14'
end_time2 = '2024-01-11 10:29:34'
filtered_df2 = lol2[(lol2['time'] >= start_time2) & (lol2['time'] <= end_time2)]

start_time3 = '2024-01-11 10:29:50'
end_time3 = '2024-01-11 10:35:02'
filtered_df3 = lol2[(lol2['time'] >= start_time3) & (lol2['time'] <= end_time3)]

start_time4 = '2024-01-11 10:35:12'
end_time4 = '2024-01-11 10:40:03'
filtered_df4 = lol2[(lol2['time'] >= start_time4) & (lol2['time'] <= end_time4)]

start_time5 = '2024-01-11 10:40:19'
end_time5 = '2024-01-11 10:46:13'
filtered_df5 = lol2[(lol2['time'] >= start_time5) & (lol2['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-11 10:18:07 and 2024-01-11 10:23:08 is: 11.75
# The mean power between 2024-01-11 10:23:14 and 2024-01-11 10:29:34 is: 41.46875
# The mean power between 2024-01-11 10:29:50 and 2024-01-11 10:35:02 is: 104.21621621621621
# The mean power between 2024-01-11 10:35:12 and 2024-01-11 10:40:03 is: 208.0487804878049
# The mean power between 2024-01-11 10:40:19 and 2024-01-11 10:46:13 is: 367.74545454545455
# Standard deviation of 'power': 0.762000762001143
# Standard deviation of 'power': 0.6712710620231424
# Standard deviation of 'power': 0.9169737405405026
# Standard deviation of 'power': 1.3592501519623812
# Standard deviation of 'power': 3.801647702316096

# %%
#59cm is about 67.05%

start_time = '2024-01-11 09:26:02'
end_time = '2024-01-11 09:50:00'
filtered_df = lol2[(lol2['time'] >= start_time) & (lol2['time'] <= end_time)]

start_time2 = '2024-01-11 09:50:11'
end_time2 = '2024-01-11 09:56:21'
filtered_df2 = lol2[(lol2['time'] >= start_time2) & (lol2['time'] <= end_time2)]

start_time3 = '2024-01-11 09:56:32'
end_time3 = '2024-01-11 10:03:03'
filtered_df3 = lol2[(lol2['time'] >= start_time3) & (lol2['time'] <= end_time3)]

start_time4 = '2024-01-11 10:03:19'
end_time4 = '2024-01-11 10:08:31'
filtered_df4 = lol2[(lol2['time'] >= start_time4) & (lol2['time'] <= end_time4)]

start_time5 = '2024-01-11 10:08:52'
end_time5 = '2024-01-11 10:14:09'
filtered_df5 = lol2[(lol2['time'] >= start_time5) & (lol2['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-11 09:26:02 and 2024-01-11 09:50:00 is: 11.3
# The mean power between 2024-01-11 09:50:11 and 2024-01-11 09:56:21 is: 40.5
# The mean power between 2024-01-11 09:56:32 and 2024-01-11 10:03:03 is: 102.18367346938776
# The mean power between 2024-01-11 10:03:19 and 2024-01-11 10:08:31 is: 206.13333333333333
# The mean power between 2024-01-11 10:08:52 and 2024-01-11 10:14:09 is: 366.84
# Standard deviation of 'power': 0.7065978881510816
# Standard deviation of 'power': 0.511766315719159
# Standard deviation of 'power': 1.013933540469885
# Standard deviation of 'power': 1.3073220372543672
# Standard deviation of 'power': 2.6905731124556693

# %%
#71cm is about 80.68%

start_time = '2024-01-11 08:47:32'
end_time = '2024-01-11 08:51:46'
filtered_df = lol2[(lol2['time'] >= start_time) & (lol2['time'] <= end_time)]

start_time2 = '2024-01-11 08:51:56'
end_time2 = '2024-01-11 09:03:50'
filtered_df2 = lol2[(lol2['time'] >= start_time2) & (lol2['time'] <= end_time2)]

start_time3 = '2024-01-11 09:04:17'
end_time3 = '2024-01-11 09:11:19'
filtered_df3 = lol2[(lol2['time'] >= start_time3) & (lol2['time'] <= end_time3)]

start_time4 = '2024-01-11 09:11:36'
end_time4 = '2024-01-11 09:16:37'
filtered_df4 = lol2[(lol2['time'] >= start_time4) & (lol2['time'] <= end_time4)]

start_time5 = '2024-01-11 09:16:47'
end_time5 = '2024-01-11 09:20:24'
filtered_df5 = lol2[(lol2['time'] >= start_time5) & (lol2['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-11 08:47:32 and 2024-01-11 08:51:46 is: 11.19047619047619
# The mean power between 2024-01-11 08:51:56 and 2024-01-11 09:03:50 is: 40.55769230769231
# The mean power between 2024-01-11 09:04:17 and 2024-01-11 09:11:19 is: 101.3265306122449
# The mean power between 2024-01-11 09:11:36 and 2024-01-11 09:16:37 is: 204.92857142857142
# The mean power between 2024-01-11 09:16:47 and 2024-01-11 09:20:24 is: 365.1111111111111
# Standard deviation of 'power': 0.7496030695673289
# Standard deviation of 'power': 0.6390391542964969
# Standard deviation of 'power': 0.9658276912843723
# Standard deviation of 'power': 1.7163895336895074
# Standard deviation of 'power': 3.7246497651478423

# %%
#79cm 89.77%

start_time = '2024-01-11 07:44:32'
end_time = '2024-01-11 07:55:01'
filtered_df = lol2[(lol2['time'] >= start_time) & (lol2['time'] <= end_time)]

start_time2 = '2024-01-11 07:55:12'
end_time2 = '2024-01-11 08:03:07'
filtered_df2 = lol2[(lol2['time'] >= start_time2) & (lol2['time'] <= end_time2)]

start_time3 = '2024-01-11 08:03:45'
end_time3 = '2024-01-11 08:11:46'
filtered_df3 = lol2[(lol2['time'] >= start_time3) & (lol2['time'] <= end_time3)]

start_time4 = '2024-01-11 08:11:56'
end_time4 = '2024-01-11 08:23:50'
filtered_df4 = lol2[(lol2['time'] >= start_time4) & (lol2['time'] <= end_time4)]

start_time5 = '2024-01-11 08:24:11'
end_time5 = '2024-01-11 08:29:17'
filtered_df5 = lol2[(lol2['time'] >= start_time5) & (lol2['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-11 07:44:32 and 2024-01-11 07:55:01 is: 10.425925925925926
# The mean power between 2024-01-11 07:55:12 and 2024-01-11 08:03:07 is: 38.81578947368421
# The mean power between 2024-01-11 08:03:45 and 2024-01-11 08:11:46 is: 97.13333333333334
# The mean power between 2024-01-11 08:11:56 and 2024-01-11 08:23:50 is: 198.66336633663366
# The mean power between 2024-01-11 08:24:11 and 2024-01-11 08:29:17 is: 357.4313725490196
# Standard deviation of 'power': 0.7164338269315373
# Standard deviation of 'power': 0.7298745970738876
# Standard deviation of 'power': 0.8726866109342774
# Standard deviation of 'power': 1.6448539614371378
# Standard deviation of 'power': 3.2140622393524634

# %%
#84cm is about 95.45%

start_time = '2024-01-11 07:09:01'
end_time = '2024-01-11 07:15:54'
filtered_df = lol2[(lol2['time'] >= start_time) & (lol2['time'] <= end_time)]

start_time2 = '2024-01-11 07:15:59'
end_time2 = '2024-01-11 07:20:07'
filtered_df2 = lol2[(lol2['time'] >= start_time2) & (lol2['time'] <= end_time2)]

start_time3 = '2024-01-11 07:20:18'
end_time3 = '2024-01-11 07:26:12'
filtered_df3 = lol2[(lol2['time'] >= start_time3) & (lol2['time'] <= end_time3)]

start_time4 = '2024-01-11 07:26:23'
end_time4 = '2024-01-11 07:31:19'
filtered_df4 = lol2[(lol2['time'] >= start_time4) & (lol2['time'] <= end_time4)]

start_time5 = '2024-01-11 07:31:40'
end_time5 = '2024-01-11 07:37:34'
filtered_df5 = lol2[(lol2['time'] >= start_time5) & (lol2['time'] <= end_time5)]

mean_power = filtered_df['power'].mean()
std_power = filtered_df['power'].std()
mean_power2 = filtered_df2['power'].mean()
std_power2 = filtered_df2['power'].std()
mean_power3 = filtered_df3['power'].mean()
std_power3 = filtered_df3['power'].std()
mean_power4 = filtered_df4['power'].mean()
std_power4 = filtered_df4['power'].std()
mean_power5 = filtered_df5['power'].mean()
std_power5 = filtered_df5['power'].std()

print(f"The mean power between {start_time} and {end_time} is: {mean_power}")
print(f"The mean power between {start_time2} and {end_time2} is: {mean_power2}")
print(f"The mean power between {start_time3} and {end_time3} is: {mean_power3}")
print(f"The mean power between {start_time4} and {end_time4} is: {mean_power4}")
print(f"The mean power between {start_time5} and {end_time5} is: {mean_power5}")
print(f"Standard deviation of 'power': {std_power}")
print(f"Standard deviation of 'power': {std_power2}")
print(f"Standard deviation of 'power': {std_power3}")
print(f"Standard deviation of 'power': {std_power4}")
print(f"Standard deviation of 'power': {std_power5}")
# Out:
# The mean power between 2024-01-11 07:09:01 and 2024-01-11 07:15:54 is: 9.104166666666666
# The mean power between 2024-01-11 07:15:59 and 2024-01-11 07:20:07 is: 32.26923076923077
# The mean power between 2024-01-11 07:20:18 and 2024-01-11 07:26:12 is: 79.11428571428571
# The mean power between 2024-01-11 07:26:23 and 2024-01-11 07:31:19 is: 159.32432432432432
# The mean power between 2024-01-11 07:31:40 and 2024-01-11 07:37:34 is: 286.5357142857143
# Standard deviation of 'power': 0.7505907838647469
# Standard deviation of 'power': 0.7775701798650618
# Standard deviation of 'power': 0.9932545604469881
# Standard deviation of 'power': 1.9156381886122622
# Standard deviation of 'power': 2.9662604907022745

# %%
mean_levels_1 = {
    'Normal without Pre-Filter': 11.884615384615385,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '58% block': 11.75,
    '67% block': 11.3,
    '75% block': 10.796296296296296,
    '81% block': 11.19047619047619,
    '90% block': 10.425925925925926,
    '95% block': 9.104166666666666,
    '99% block': 8.0
}

mean_levels_2 = {
    'Normal without Pre-Filter': 42.96666666666667,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '58% block': 41.46875,
    '67% block': 40.5,
    '75% block': 39.888888888888886,
    '81% block': 40.55769230769231,
    '90% block': 38.81578947368421,
    '95% block': 32.26923076923077,
    '99% block': 24.48
}

mean_levels_3 = {
    'Normal without Pre-Filter': 105.43333333333334,
    '25% block': 105.73684210526316,
    '50% block': 104.23404255319149,
    '58% block': 104.21621621621621,
    '67% block': 102.18367346938776,
    '75% block': 101.06060606060606,
    '81% block': 101.3265306122449,
    '90% block': 97.13333333333334,
    '95% block': 79.11428571428571,
    '99% block': 54.714285714285715
}

mean_levels_4 = {
    'Normal without Pre-Filter': 209.07692307692307,
    '25% block': 209.4047619047619,
    '50% block': 209.25581395348837,
    '58% block': 208.0487804878049,
    '67% block': 206.13333333333333,
    '75% block': 204.08064516129033,
    '81% block': 204.92857142857142,
    '90% block': 198.66336633663366,
    '95% block': 159.32432432432432,
    '99% block': 103.83333333333333
}

mean_levels_5 = {
    'Normal without Pre-Filter': 365.04545454545456,
    '25% block': 368.5581395348837,
    '50% block': 370.14285714285717,
    '58% block': 367.74545454545455,
    '67% block': 366.84,
    '75% block': 365.8510638297872,
    '81% block': 365.1111111111111,
    '90% block': 357.4313725490196,
    '95% block': 286.5357142857143,
    '99% block': 175.54
}

# %% [markdown]
# 84cm is about 95.45%
# 79cm is about 89.77%
# 71cm is about 80.68%
# 59cm is about 67.05%
# 51cm is about 57.95%

# %% [markdown]
# # STD

# %%
import matplotlib.pyplot as plt
import numpy as np

mean_levels_1 = {
    'Normal': 11.884615384615385,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '75% block': 10.796296296296296,
    '99% block': 8.0
}

standard_deviation_levels_1 = {
    'Normal': 0.8161824833662178,
    '25% block': 0.7790276362049131,
    '50% block': 0.6610377786964038,
    '75% block': 0.8098364528492048,
    '99% block': 0.7844645405527362
}

mean_levels_2 = {
    'Normal': 42.96666666666667,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '75% block': 39.888888888888886,
    '99% block': 24.48
}

standard_deviation_levels_2 = {
    'Normal': 0.7648904962570576,
    '25% block': 0.7790276362049131,
    '50% block': 0.7060180864974624,
    '75% block': 0.6855106213838522,
    '99% block': 0.6979824404521128
}

mean_levels_3 = {
    'Normal': 105.43333333333334,
    '25% block': 105.73684210526316,
    '50% block': 104.23404255319149,
    '75% block': 101.06060606060606,
    '99% block': 54.714285714285715
}

standard_deviation_levels_3 = {
    'Normal': 0.6789105539243627,
    '25% block': 0.7790276362049131,
    '50% block': 0.8395849377609622,
    '75% block': 0.8268688657895648,
    '99% block': 0.8934871726729446
}

mean_levels_4 = {
    'Normal': 209.07692307692307,
    '25% block': 209.4047619047619,
    '50% block': 209.25581395348837,
    '75% block': 204.08064516129033,
    '99% block': 103.83333333333333
}

standard_deviation_levels_4 = {
    'Normal': 1.493575987611354,
    '25% block': 1.5469801236291307,
    '50% block': 1.4157788241276543,
    '75% block': 1.6124351515416127,
    '99% block': 1.4636517423090194
}

mean_levels_5 = {
    'Normal': 365.04545454545456,
    '25% block': 368.5581395348837,
    '50% block': 370.14285714285717,
    '75% block': 365.8510638297872,
    '99% block': 175.54
}

standard_deviation_levels_5 = {
    'Normal': 3.2845979220467365,
    '25% block': 2.6574452964973654,
    '50% block': 3.3609771268764623,
    '75% block': 2.835939560619965,
    '99% block': 3.0852512880159506
}

for data in [mean_levels_1, standard_deviation_levels_1,
             mean_levels_2, standard_deviation_levels_2,
             mean_levels_3, standard_deviation_levels_3,
             mean_levels_4, standard_deviation_levels_4,
             mean_levels_5, standard_deviation_levels_5]:
    data.pop('Removed filter', None)

x = np.arange(len(mean_levels_1)) 

plt.figure(figsize=(12, 8))
width = 0.15  
plt.bar(x - 2*width, list(mean_levels_1.values()), width, yerr=list(standard_deviation_levels_1.values()), capsize=5, label='Level 1')
plt.bar(x - width, list(mean_levels_2.values()), width, yerr=list(standard_deviation_levels_2.values()), capsize=5, label='Level 2')
plt.bar(x, list(mean_levels_3.values()), width, yerr=list(standard_deviation_levels_3.values()), capsize=5, label='Level 3')
plt.bar(x + width, list(mean_levels_4.values()), width, yerr=list(standard_deviation_levels_4.values()), capsize=5, label='Level 4')
plt.bar(x + 2*width, list(mean_levels_5.values()), width, yerr=list(standard_deviation_levels_5.values()), capsize=5, label='Level 5')
plt.xlabel('Mean Levels')
plt.ylabel('Mean Value')
plt.title('Histogram of Mean Levels with Standard Deviation')
plt.xticks(x, list(mean_levels_1.keys()))
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

mean_levels_1 = {
    #'Normal': 11.11111111111111,
    'Normal without Pre-Filter': 11.884615384615385,
    #'Removed filter': 11.194444444444445,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '75% block': 10.796296296296296,
    '99% block': 8.0
}

mean_levels_2 = {
    #'Normal': 42.0,
    'Normal without Pre-Filter': 42.96666666666667,
    #'Removed filter': 38.1875,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '75% block': 39.888888888888886,
    '99% block': 24.48
}

names_1 = list(mean_levels_1.keys())
values_1 = list(mean_levels_1.values())

names_2 = list(mean_levels_2.keys())
values_2 = list(mean_levels_2.values())

x = names_1 

plt.scatter(x, values_1, label='Mean Levels 1')
z1 = np.polyfit(range(1, len(values_1) + 1), values_1, 3) 
p1 = np.poly1d(z1)
plt.plot(names_1, p1(range(1, len(values_1) + 1)), label='Curve Fit 1', color='red')


plt.scatter(x, values_2, label='Mean Levels 2')
z2 = np.polyfit(range(1, len(values_2) + 1), values_2, 3) 
p2 = np.poly1d(z2)
plt.plot(names_1, p2(range(1, len(values_2) + 1)), label='Curve Fit 2',  color='blue')

plt.xlabel('Mean Name')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels')

plt.legend(fontsize='small')

plt.xticks(rotation=45)  
plt.tight_layout()  
plt.show()


print("Polynomial equation for line 1:")
print(p1)


print("Polynomial equation for line 2:")
print(p2)
# Out:
# Polynomial equation for line 1:
#         3         2
# -0.255 x + 1.935 x - 4.676 x + 14.88
# Polynomial equation for line 2:
#         3         2
# -1.099 x + 7.683 x - 16.65 x + 53.21

# %%
import matplotlib.pyplot as plt
import numpy as np

mean_levels_1 = {
    '0% block': 11.884615384615385,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '58% block': 11.75,
    '67% block': 11.3,
    '75% block': 10.796296296296296,
    '81% block': 11.19047619047619,
    '90% block': 10.425925925925926,
    '95% block': 9.104166666666666,
    '99% block': 8.0
}

mean_levels_2 = {
    '0% block': 42.96666666666667,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '58% block': 41.46875,
    '67% block': 40.5,
    '75% block': 39.888888888888886,
    '81% block': 40.55769230769231,
    '90% block': 38.81578947368421,
    '95% block': 32.26923076923077,
    '99% block': 24.48
}

mean_levels_3 = {
    '0% block': 105.43333333333334,
    '25% block': 105.73684210526316,
    '50% block': 104.23404255319149,
    '58% block': 104.21621621621621,
    '67% block': 102.18367346938776,
    '75% block': 101.06060606060606,
    '81% block': 101.3265306122449,
    '90% block': 97.13333333333334,
    '95% block': 79.11428571428571,
    '99% block': 54.714285714285715
}

mean_levels_4 = {
    '0% block': 209.07692307692307,
    '25% block': 209.4047619047619,
    '50% block': 209.25581395348837,
    '58% block': 208.0487804878049,
    '67% block': 206.13333333333333,
    '75% block': 204.08064516129033,
    '81% block': 204.92857142857142,
    '90% block': 198.66336633663366,
    '95% block': 159.32432432432432,
    '99% block': 103.83333333333333
}

mean_levels_5 = {
    '0% block': 365.04545454545456,
    '25% block': 368.5581395348837,
    '50% block': 370.14285714285717,
    '58% block': 367.74545454545455,
    '67% block': 366.84,
    '75% block': 365.8510638297872,
    '81% block': 365.1111111111111,
    '90% block': 357.4313725490196,
    '95% block': 286.5357142857143,
    '99% block': 175.54
}


names_1 = list(mean_levels_1.keys())
values_1 = list(mean_levels_1.values())

names_2 = list(mean_levels_2.keys())
values_2 = list(mean_levels_2.values())

names_3 = list(mean_levels_3.keys())
values_3 = list(mean_levels_3.values())

names_4 = list(mean_levels_4.keys())
values_4 = list(mean_levels_4.values())

names_5 = list(mean_levels_5.keys())
values_5 = list(mean_levels_5.values())


x = names_1  

plt.scatter(x, values_1, label='Mean Levels 1')
z1 = np.polyfit(range(1, len(values_1) + 1), values_1, 3) 
p1 = np.poly1d(z1)
plt.plot(names_1, p1(range(1, len(values_1) + 1)), label='Curve Fit 1', color='red')

plt.scatter(x, values_2, label='Mean Levels 2')
z2 = np.polyfit(range(1, len(values_2) + 1), values_2, 3)  
p2 = np.poly1d(z2)
plt.plot(names_1, p2(range(1, len(values_2) + 1)), label='Curve Fit 2', linestyle='--', color='blue')

plt.scatter(x, values_3, label='Mean Levels 3')
z3 = np.polyfit(range(1, len(values_3) + 1), values_3, 3) 
p3 = np.poly1d(z3)
plt.plot(names_1, p3(range(1, len(values_3) + 1)), label='Curve Fit 3', linestyle=':', color='green')

plt.scatter(x, values_4, label='Mean Levels 4')
z4 = np.polyfit(range(1, len(values_4) + 1), values_4, 3) 
p4 = np.poly1d(z4)
plt.plot(names_1, p4(range(1, len(values_4) + 1)), label='Curve Fit 4', color='yellow')


plt.scatter(x, values_5, label='Mean Levels 5')
z5 = np.polyfit(range(1, len(values_5) + 1), values_5, 3)  
p5 = np.poly1d(z5)
plt.plot(names_1, p5(range(1, len(values_5) + 1)), label='Curve Fit 5', color='yellow')



plt.xlabel('Mean Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()

print("Polynomial equation for line 1:")
print(p1)

print("Polynomial equation for line 2:")
print(p2)

print("Polynomial equation for line 3 (level 3):")
print(p3)

print("Polynomial equation for line 4:")
print(p4)

print("Polynomial equation for line 5:")
print(p5)
# Out:
# Polynomial equation for line 1:
#           3          2
# -0.01478 x + 0.1714 x - 0.6724 x + 12.27
# Polynomial equation for line 2:
#           3         2
# -0.09648 x + 1.237 x - 4.984 x + 47.51
# Polynomial equation for line 3 (level 3):
#          3         2
# -0.2731 x + 3.368 x - 12.44 x + 116.9
# Polynomial equation for line 4:
#          3         2
# -0.6268 x + 7.795 x - 27.93 x + 234.4
# Polynomial equation for line 5:
#         3         2
# -1.218 x + 15.17 x - 52.68 x + 413.2

# %%
import matplotlib.pyplot as plt
import numpy as np

mean_levels_1 = {
    '0% block': 11.884615384615385,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '58% block': 11.75,
    '67% block': 11.3,
    '75% block': 10.796296296296296,
    '81% block': 11.19047619047619,
    '90% block': 10.425925925925926,
    '95% block': 9.104166666666666,
    '99% block': 8.0
}

mean_levels_2 = {
    '0% block': 42.96666666666667,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '58% block': 41.46875,
    '67% block': 40.5,
    '75% block': 39.888888888888886,
    '81% block': 40.55769230769231,
    '90% block': 38.81578947368421,
    '95% block': 32.26923076923077,
    '99% block': 24.48
}

names_1 = list(mean_levels_1.keys())
values_1 = list(mean_levels_1.values())

names_2 = list(mean_levels_2.keys())
values_2 = list(mean_levels_2.values())

percentage_levels = [0, 25, 50, 58, 67, 75, 81, 90, 95, 99]

plt.scatter(percentage_levels, values_1, label='Mean Levels 1', color='red')

plt.scatter(percentage_levels, values_2, label='Mean Levels 2', color='blue')

plt.xlabel('Percentage Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()  
plt.show()
# Out:
# Polynomial equation for line 1:
#             2
# -0.0006689 x + 0.04135 x + 11.41
# Polynomial equation for line 2:
#            2
# -0.003122 x + 0.1984 x + 41.45
# Polynomial equation for line 3 (level 3):
#            2
# -0.009523 x + 0.6612 x + 100.9
# Polynomial equation for line 4:
#           2
# -0.02021 x + 1.464 x + 198.8
# Polynomial equation for line 5:
#           2
# -0.03757 x + 2.834 x + 345.7

# %%
import matplotlib.pyplot as plt
import numpy as np

mean_levels_1 = {
    '0% block': 11.884615384615385,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '58% block': 11.75,
    '67% block': 11.3,
    '75% block': 10.796296296296296,
    '81% block': 11.19047619047619,
    '90% block': 10.425925925925926,
    '95% block': 9.104166666666666,
    '99% block': 8.0
}

mean_levels_2 = {
    '0% block': 42.96666666666667,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '58% block': 41.46875,
    '67% block': 40.5,
    '75% block': 39.888888888888886,
    '81% block': 40.55769230769231,
    '90% block': 38.81578947368421,
    '95% block': 32.26923076923077,
    '99% block': 24.48
}

mean_levels_3 = {
    '0% block': 105.43333333333334,
    '25% block': 105.73684210526316,
    '50% block': 104.23404255319149,
    '58% block': 104.21621621621621,
    '67% block': 102.18367346938776,
    '75% block': 101.06060606060606,
    '81% block': 101.3265306122449,
    '90% block': 97.13333333333334,
    '95% block': 79.11428571428571,
    '99% block': 54.714285714285715
}

mean_levels_4 = {
    '0% block': 209.07692307692307,
    '25% block': 209.4047619047619,
    '50% block': 209.25581395348837,
    '58% block': 208.0487804878049,
    '67% block': 206.13333333333333,
    '75% block': 204.08064516129033,
    '81% block': 204.92857142857142,
    '90% block': 198.66336633663366,
    '95% block': 159.32432432432432,
    '99% block': 103.83333333333333
}

mean_levels_5 = {
    '0% block': 365.04545454545456,
    '25% block': 368.5581395348837,
    '50% block': 370.14285714285717,
    '58% block': 367.74545454545455,
    '67% block': 366.84,
    '75% block': 365.8510638297872,
    '81% block': 365.1111111111111,
    '90% block': 357.4313725490196,
    '95% block': 286.5357142857143,
    '99% block': 175.54
}

names_1 = list(mean_levels_1.keys())
values_1 = list(mean_levels_1.values())

names_2 = list(mean_levels_2.keys())
values_2 = list(mean_levels_2.values())

names_3 = list(mean_levels_3.keys())
values_3 = list(mean_levels_3.values())

names_4 = list(mean_levels_4.keys())
values_4 = list(mean_levels_4.values())

names_5 = list(mean_levels_5.keys())
values_5 = list(mean_levels_5.values())

percentage_levels = [0, 25, 50, 58, 67, 75, 81, 90, 95, 99]

plt.scatter(percentage_levels, values_1, label='Mean Levels 1')
z1 = np.polyfit(percentage_levels, values_1, 2) 
p1 = np.poly1d(z1)
plt.plot(percentage_levels, p1(percentage_levels), label='Curve Fit 1', color='red')

plt.scatter(percentage_levels, values_2, label='Mean Levels 2')
z2 = np.polyfit(percentage_levels, values_2, 2) 
p2 = np.poly1d(z2)
plt.plot(percentage_levels, p2(percentage_levels), label='Curve Fit 2', linestyle='--', color='blue')

plt.scatter(percentage_levels, values_3, label='Mean Levels 3')
z3 = np.polyfit(percentage_levels, values_3, 2) 
p3 = np.poly1d(z3)
plt.plot(percentage_levels, p3(percentage_levels), label='Curve Fit 3', linestyle=':', color='green')

plt.scatter(percentage_levels, values_4, label='Mean Levels 4')
z4 = np.polyfit(percentage_levels, values_4, 2)
p4 = np.poly1d(z4)
plt.plot(percentage_levels, p4(percentage_levels), label='Curve Fit 4', color='yellow')

plt.scatter(percentage_levels, values_5, label='Mean Levels 5')
z5 = np.polyfit(percentage_levels, values_5, )
p5 = np.poly1d(z5)
plt.plot(percentage_levels, p5(percentage_levels), label='Curve Fit 5', color='black')

plt.xlabel('Percentage Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout() 
plt.show()

print("Polynomial equation for line 1:")
print(p1)

print("Polynomial equation for line 2:")
print(p2)

print("Polynomial equation for line 3 (level 3):")
print(p3)

print("Polynomial equation for line 4:")
print(p4)

print("Polynomial equation for line 5:")
print(p5)
# Out:
# Polynomial equation for line 1:
#             2
# -0.0006689 x + 0.04135 x + 11.41
# Polynomial equation for line 2:
#            2
# -0.003122 x + 0.1984 x + 41.45
# Polynomial equation for line 3 (level 3):
#            2
# -0.009523 x + 0.6612 x + 100.9
# Polynomial equation for line 4:
#           2
# -0.02021 x + 1.464 x + 198.8
# Polynomial equation for line 5:
#           2
# -0.03757 x + 2.834 x + 345.7

# %%
import matplotlib.pyplot as plt
import numpy as np

mean_levels_1 = {
    '0% block': 11.884615384615385,
    '25% block': 11.208333333333334,
    '50% block': 11.404255319148936,
    '58% block': 11.75,
    '67% block': 11.3,
    '75% block': 10.796296296296296,
    '81% block': 11.19047619047619,
    '90% block': 10.425925925925926,
    '95% block': 9.104166666666666,
    '99% block': 8.0
}

mean_levels_2 = {
    '0% block': 42.96666666666667,
    '25% block': 42.53846153846154,
    '50% block': 41.68421052631579,
    '58% block': 41.46875,
    '67% block': 40.5,
    '75% block': 39.888888888888886,
    '81% block': 40.55769230769231,
    '90% block': 38.81578947368421,
    '95% block': 32.26923076923077,
    '99% block': 24.48
}

mean_levels_3 = {
    '0% block': 105.43333333333334,
    '25% block': 105.73684210526316,
    '50% block': 104.23404255319149,
    '58% block': 104.21621621621621,
    '67% block': 102.18367346938776,
    '75% block': 101.06060606060606,
    '81% block': 101.3265306122449,
    '90% block': 97.13333333333334,
    '95% block': 79.11428571428571,
    '99% block': 54.714285714285715
}

mean_levels_4 = {
    '0% block': 209.07692307692307,
    '25% block': 209.4047619047619,
    '50% block': 209.25581395348837,
    '58% block': 208.0487804878049,
    '67% block': 206.13333333333333,
    '75% block': 204.08064516129033,
    '81% block': 204.92857142857142,
    '90% block': 198.66336633663366,
    '95% block': 159.32432432432432,
    '99% block': 103.83333333333333
}

mean_levels_5 = {
    '0% block': 365.04545454545456,
    '25% block': 368.5581395348837,
    '50% block': 370.14285714285717,
    '58% block': 367.74545454545455,
    '67% block': 366.84,
    '75% block': 365.8510638297872,
    '81% block': 365.1111111111111,
    '90% block': 357.4313725490196,
    '95% block': 286.5357142857143,
    '99% block': 175.54
}

names_1 = list(mean_levels_1.keys())
values_1 = list(mean_levels_1.values())

names_2 = list(mean_levels_2.keys())
values_2 = list(mean_levels_2.values())

names_3 = list(mean_levels_3.keys())
values_3 = list(mean_levels_3.values())

names_4 = list(mean_levels_4.keys())
values_4 = list(mean_levels_4.values())

names_5 = list(mean_levels_5.keys())
values_5 = list(mean_levels_5.values())

percentage_levels = [0, 25, 50, 58, 67, 75, 81, 90, 95, 99]

plt.scatter(percentage_levels, values_1, label='Mean Levels 1', color='red')
plt.scatter(percentage_levels, values_2, label='Mean Levels 2', color='blue')
plt.scatter(percentage_levels, values_3, label='Mean Levels 3')
plt.scatter(percentage_levels, values_4, label='Mean Levels 4')
plt.scatter(percentage_levels, values_5, label='Mean Levels 5')

plt.xlabel('Percentage Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Values')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout() 
plt.show()

# %%
print(values_1)
print(percentage_levels)

def curve_fit_formula(x, a, b, c, d):
    return a - b**(d * x - c)

params, covariance = curve_fit(curve_fit_formula, percentage_levels, values_1)
print(params)
curve_fit_values = curve_fit_formula(percentage_levels, *params)

plt.scatter(percentage_levels, values_1, label=label)

plt.plot(percentage_levels, curve_fit_values, '--')
# Out:
# [11.884615384615385, 11.208333333333334, 11.404255319148936, 11.75, 11.3, 10.796296296296296, 11.19047619047619, 10.425925925925926, 9.104166666666666, 8.0]
# [ 0 25 50 58 67 75 81 90 95 99]
# [ 11.4998653    1.06845815 147.60442493   1.68295021]

# %%
print(values_2)
print(percentage_levels)

def curve_fit_formula(x, a, b, c, d):
    return a - b**(d * x - c)

params, covariance = curve_fit(curve_fit_formula, percentage_levels, values_2,p0=[43,1.006,2,140])

curve_fit_values = curve_fit_formula(percentage_levels, *params)

plt.scatter(percentage_levels, values_2, label=label)

plt.plot(percentage_levels, curve_fit_values, '--')
# Out:
# [42.96666666666667, 42.53846153846154, 41.68421052631579, 41.46875, 40.5, 39.888888888888886, 39.55769230769231, 38.81578947368421, 32.26923076923077, 24.48]
# [ 0 25 50 58 67 75 81 90 95 99]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

mean_levels_data = {
    'Mean Levels 1': {
        '0% block': 11.884615384615385,
        '25% block': 11.208333333333334,
        '50% block': 11.404255319148936,
        '58% block': 11.75,
        '67% block': 11.3,
        '75% block': 10.796296296296296,
        '81% block': 11.19047619047619,
        '90% block': 10.425925925925926,
        '95% block': 9.104166666666666,
        '99% block': 8.0
    },
    'Mean Levels 2': {
        '0% block': 42.96666666666667,
        '25% block': 42.53846153846154,
        '50% block': 41.68421052631579,
        '58% block': 41.46875,
        '67% block': 40.5,
        '75% block': 39.888888888888886,
        '81% block': 40.55769230769231,
        '90% block': 38.81578947368421,
        '95% block': 32.26923076923077,
        '99% block': 24.48
    },
    'Mean Levels 3': {
        '0% block': 105.43333333333334,
        '25% block': 105.73684210526316,
        '50% block': 104.23404255319149,
        '58% block': 104.21621621621621,
        '67% block': 102.18367346938776,
        '75% block': 101.06060606060606,
        '81% block': 101.3265306122449,
        '90% block': 97.13333333333334,
        '95% block': 79.11428571428571,
        '99% block': 54.714285714285715
    },
    'Mean Levels 4': {
        '0% block': 209.07692307692307,
        '25% block': 209.4047619047619,
        '50% block': 209.25581395348837,
        '58% block': 208.0487804878049,
        '67% block': 206.13333333333333,
        '75% block': 204.08064516129033,
        '81% block': 204.92857142857142,
        '90% block': 198.66336633663366,
        '95% block': 159.32432432432432,
        '99% block': 103.83333333333333
    },
    'Mean Levels 5': {
        '0% block': 365.04545454545456,
        '25% block': 368.5581395348837,
        '50% block': 370.14285714285717,
        '58% block': 367.74545454545455,
        '67% block': 366.84,
        '75% block': 365.8510638297872,
        '81% block': 365.1111111111111,
        '90% block': 357.4313725490196,
        '95% block': 286.5357142857143,
        '99% block': 175.54
    },
}

percentage_levels = np.array([0, 25, 50, 58, 67, 75, 81, 90, 95, 99])

def curve_fit_formula(x, a, b, c, d):
    return a - b**(d * x - c)

for label, mean_levels in mean_levels_data.items():
    names = list(mean_levels.keys())
    values = list(mean_levels.values())

    if label == 'Mean Levels 1':
        initial_params = [12, 2, 1, 1]
    elif label == 'Mean Levels 2':
        initial_params = [43,1.006,2,140]
    elif label == 'Mean Levels 3':
        initial_params = [110, 1.006,2,140]
    elif label == 'Mean Levels 4':
        initial_params = [210, 1.006,2,140]
    elif label == 'Mean Levels 5':
        initial_params = [370, 1.006,2,140]

    params, covariance = curve_fit(curve_fit_formula, percentage_levels, values, p0=initial_params)

    curve_fit_values = curve_fit_formula(percentage_levels, *params)


    formula = f"{params[0]:.2f} - {params[1]:.2f}^({params[3]:.2f} * x - {params[2]:.2f})"
    print(f"{label} - Formula: {formula}")
    print(f"{label} - Fitted Parameters: {params}")

    plt.scatter(percentage_levels, values, label=label)

    plt.plot(percentage_levels, curve_fit_values, '--')

plt.xlabel('Percentage Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels with Sigmoidal Curve Fit')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout() 
plt.show()
# Out:
# Mean Levels 1 - Formula: 11.50 - 1.10^(1.21 * x - 106.02)
# Mean Levels 1 - Fitted Parameters: [ 11.49985491   1.09657719 106.01799797   1.20878781]
# Mean Levels 2 - Formula: 41.64 - 1.03^(5.07 * x - 414.89)
# Mean Levels 2 - Fitted Parameters: [ 41.63936204   1.03343448 414.8885173    5.06525109]
# Mean Levels 3 - Formula: 103.99 - 1.03^(6.07 * x - 474.26)
# Mean Levels 3 - Fitted Parameters: [103.98537014   1.03121801 474.26200524   6.07299444]
# Mean Levels 4 - Formula: 208.10 - 1.00^(50.50 * x - 3899.89)
# Mean Levels 4 - Fitted Parameters: [2.08100205e+02 1.00424106e+00 3.89988718e+03 5.05044621e+01]
# Mean Levels 5 - Formula: 368.29 - 1.00^(51.50 * x - 3970.34)
# Mean Levels 5 - Fitted Parameters: [3.68291311e+02 1.00468285e+00 3.97034212e+03 5.14975853e+01]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score, mean_squared_error

mean_levels_data = {
    'Mean Levels 1': {
        '0% block': 11.884615384615385,
        '25% block': 11.208333333333334,
        '50% block': 11.404255319148936,
        '58% block': 11.75,
        '67% block': 11.3,
        '75% block': 10.796296296296296,
        '81% block': 11.19047619047619,
        '90% block': 10.425925925925926,
        '95% block': 9.104166666666666,
        '99% block': 8.0
    },
    'Mean Levels 2': {
        '0% block': 42.96666666666667,
        '25% block': 42.53846153846154,
        '50% block': 41.68421052631579,
        '58% block': 41.46875,
        '67% block': 40.5,
        '75% block': 39.888888888888886,
        '81% block': 40.55769230769231,
        '90% block': 38.81578947368421,
        '95% block': 32.26923076923077,
        '99% block': 24.48
    },
    'Mean Levels 3': {
        '0% block': 105.43333333333334,
        '25% block': 105.73684210526316,
        '50% block': 104.23404255319149,
        '58% block': 104.21621621621621,
        '67% block': 102.18367346938776,
        '75% block': 101.06060606060606,
        '81% block': 101.3265306122449,
        '90% block': 97.13333333333334,
        '95% block': 79.11428571428571,
        '99% block': 54.714285714285715
    },
    'Mean Levels 4': {
        '0% block': 209.07692307692307,
        '25% block': 209.4047619047619,
        '50% block': 209.25581395348837,
        '58% block': 208.0487804878049,
        '67% block': 206.13333333333333,
        '75% block': 204.08064516129033,
        '81% block': 204.92857142857142,
        '90% block': 198.66336633663366,
        '95% block': 159.32432432432432,
        '99% block': 103.83333333333333
    },
    'Mean Levels 5': {
        '0% block': 365.04545454545456,
        '25% block': 368.5581395348837,
        '50% block': 370.14285714285717,
        '58% block': 367.74545454545455,
        '67% block': 366.84,
        '75% block': 365.8510638297872,
        '81% block': 365.1111111111111,
        '90% block': 357.4313725490196,
        '95% block': 286.5357142857143,
        '99% block': 175.54
    },
}

percentage_levels = np.array([0, 25, 50, 58, 67, 75, 81, 90, 95, 99])

def curve_fit_formula(x, a, b, c, d):
    return a - b**(c * x - d)

r_squared_values = []
mse_values = []
covariance_matrices = []
for label, mean_levels in mean_levels_data.items():
    names = list(mean_levels.keys())
    values = list(mean_levels.values())

    if label == 'Mean Levels 1':
        initial_params = [12, 2, 1, 1]
    elif label == 'Mean Levels 2':
        initial_params = [43, 1.006, 2, 140]
    elif label == 'Mean Levels 3':
        initial_params = [110, 1.006, 2, 140]
    elif label == 'Mean Levels 4':
        initial_params = [210, 1.006, 2, 140]
    elif label == 'Mean Levels 5':
        initial_params = [370, 1.006, 2, 140]

    params, covariance = curve_fit(curve_fit_formula, percentage_levels, values, p0=initial_params)

    curve_fit_values = curve_fit_formula(percentage_levels, *params)

    formula = f"{params[0]:.2f} - {params[1]:.2f}^({params[2]:.2f} * x - {params[3]:.2f})"
    print(f"{label} - Formula: {formula}")
    print(f"{label} - Fitted Parameters: {params}")

    r_squared = r2_score(values, curve_fit_values)
    mse = mean_squared_error(values, curve_fit_values)
    
    r_squared_values.append(r_squared)
    mse_values.append(mse)
    covariance_matrices.append(covariance)
    plt.scatter(percentage_levels, values, label=label)

    plt.plot(percentage_levels, curve_fit_values, '--')

plt.xlabel('Percentage Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels with Exponential Curve Fit')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout() 
plt.show()

for label, r_squared, mse, covariance_matrix in zip(mean_levels_data.keys(), r_squared_values, mse_values, covariance_matrices):
    print(f"{label} - R-squared: {r_squared:.4f}, MSE: {mse:.4f}")
# Out:
# Mean Levels 1 - Formula: 11.50 - 1.10^(1.21 * x - 106.02)
# Mean Levels 1 - Fitted Parameters: [ 11.49985491   1.09657719   1.20878781 106.01799797]
# Mean Levels 2 - Formula: 41.64 - 1.06^(3.07 * x - 251.51)
# Mean Levels 2 - Fitted Parameters: [ 41.63943271   1.05574573   3.07067399 251.51248752]
# Mean Levels 3 - Formula: 103.99 - 1.04^(4.72 * x - 368.88)
# Mean Levels 3 - Fitted Parameters: [103.9853716    1.04031433   4.7235303  368.87744968]
# Mean Levels 4 - Formula: 208.10 - 1.05^(4.21 * x - 324.91)
# Mean Levels 4 - Fitted Parameters: [208.10020817   1.05211032   4.20763703 324.90807684]
# Mean Levels 5 - Formula: 368.29 - 1.05^(4.94 * x - 381.15)
# Mean Levels 5 - Fitted Parameters: [368.29129521   1.0498694    4.94378437 381.15423407]
# C:\Users\Mathi\AppData\Local\Temp\ipykernel_21340\592361071.py:75: RuntimeWarning: invalid value encountered in power
#   return a - b**(c * x - d)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

params, covariance = curve_fit(curve_fit_formula, percentage_levels, values, p0=initial_params)

print(f"{label} - Covariance Matrix:")
print(covariance)

plt.figure(figsize=(8, 6))
sns.heatmap(covariance, annot=True, fmt=".4f", cmap="coolwarm", square=True)
plt.title(f"{label} - Covariance Matrix Heatmap")
plt.show()

# ...
# Out:
# C:\Users\Mathi\AppData\Local\Temp\ipykernel_21340\2532625819.py:75: RuntimeWarning: invalid value encountered in power
#   return a - b**(c * x - d)
# Mean Levels 5 - Covariance Matrix:
# [[ 6.11752456e+00  5.03204062e+04 -4.86906053e+06 -3.75393366e+08]
#  [ 5.03204062e+04  2.70323856e+09 -2.61568461e+11 -2.01663262e+13]
#  [-4.86906053e+06 -2.61568461e+11  2.53096640e+13  1.95131683e+15]
#  [-3.75393366e+08 -2.01663262e+13  1.95131683e+15  1.50442036e+17]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score, mean_squared_error

mean_levels_data = {
    'Mean Levels 1': {
        '0% block': 11.884615384615385,
        '25% block': 11.208333333333334,
        '50% block': 11.404255319148936,
        '58% block': 11.75,
        '67% block': 11.3,
        '75% block': 10.796296296296296,
        '81% block': 11.19047619047619,
        '90% block': 10.425925925925926,
        '95% block': 9.104166666666666,
        '99% block': 8.0
    },
    'Mean Levels 2': {
        '0% block': 42.96666666666667,
        '25% block': 42.53846153846154,
        '50% block': 41.68421052631579,
        '58% block': 41.46875,
        '67% block': 40.5,
        '75% block': 39.888888888888886,
        '81% block': 40.55769230769231,
        '90% block': 38.81578947368421,
        '95% block': 32.26923076923077,
        '99% block': 24.48
    },
    'Mean Levels 3': {
        '0% block': 105.43333333333334,
        '25% block': 105.73684210526316,
        '50% block': 104.23404255319149,
        '58% block': 104.21621621621621,
        '67% block': 102.18367346938776,
        '75% block': 101.06060606060606,
        '81% block': 101.3265306122449,
        '90% block': 97.13333333333334,
        '95% block': 79.11428571428571,
        '99% block': 54.714285714285715
    },
    'Mean Levels 4': {
        '0% block': 209.07692307692307,
        '25% block': 209.4047619047619,
        '50% block': 209.25581395348837,
        '58% block': 208.0487804878049,
        '67% block': 206.13333333333333,
        '75% block': 204.08064516129033,
        '81% block': 204.92857142857142,
        '90% block': 198.66336633663366,
        '95% block': 159.32432432432432,
        '99% block': 103.83333333333333
    },
    'Mean Levels 5': {
        '0% block': 365.04545454545456,
        '25% block': 368.5581395348837,
        '50% block': 370.14285714285717,
        '58% block': 367.74545454545455,
        '67% block': 366.84,
        '75% block': 365.8510638297872,
        '81% block': 365.1111111111111,
        '90% block': 357.4313725490196,
        '95% block': 286.5357142857143,
        '99% block': 175.54
    },
}

percentage_levels = np.array([0, 25, 50, 58, 67, 75, 81, 90, 95, 99])

def curve_fit_formula(x, a, b, c, d):
    return a - b**(c * x - d)

r_squared_values = []
mse_values = []

covariance_matrices = []

for label, mean_levels in mean_levels_data.items():
    names = list(mean_levels.keys())
    values = list(mean_levels.values())

    if label == 'Mean Levels 1':
        initial_params = [12, 2, 1, 1]
    elif label == 'Mean Levels 2':
        initial_params = [43, 1.006, 2, 140]
    elif label == 'Mean Levels 3':
        initial_params = [110, 1.006, 2, 140]
    elif label == 'Mean Levels 4':
        initial_params = [210, 1.006, 2, 140]
    elif label == 'Mean Levels 5':
        initial_params = [370, 1.006, 2, 140]

    params, covariance = curve_fit(curve_fit_formula, percentage_levels, values, p0=initial_params)

    covariance_matrices.append(covariance)

    curve_fit_values = curve_fit_formula(percentage_levels, *params)

    formula = f"{params[0]:.2f} - {params[1]:.2f}^({params[2]:.2f} * x - {params[3]:.2f})"
    print(f"{label} - Formula: {formula}")
    print(f"{label} - Fitted Parameters: {params}")

    r_squared = r2_score(values, curve_fit_values)
    mse = mean_squared_error(values, curve_fit_values)

    r_squared_values.append(r_squared)
    mse_values.append(mse)

    plt.scatter(percentage_levels, values, label=label)

    plt.plot(percentage_levels, curve_fit_values, '--')

plt.xlabel('Percentage Level')
plt.ylabel('Mean Value')
plt.title('Trend of Mean Levels with Sigmoidal Curve Fit')

plt.legend(fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()  
plt.show()

for label, r_squared, mse in zip(mean_levels_data.keys(), r_squared_values, mse_values):
    print(f"{label} - R-squared: {r_squared:.4f}, MSE: {mse:.4f}")

plt.figure()
plt.imshow(covariance_matrices[-1], cmap='viridis', interpolation='none', aspect='auto')
plt.colorbar()
plt.title(f'Covariance Matrix - {label}')
plt.xlabel('Parameter Index')
plt.ylabel('Parameter Index')
plt.show()
# Out:
# Mean Levels 1 - Formula: 11.50 - 1.10^(1.21 * x - 106.02)
# Mean Levels 1 - Fitted Parameters: [ 11.49985491   1.09657719   1.20878781 106.01799797]
# Mean Levels 2 - Formula: 41.64 - 1.06^(3.07 * x - 251.51)
# Mean Levels 2 - Fitted Parameters: [ 41.63943271   1.05574573   3.07067399 251.51248752]
# Mean Levels 3 - Formula: 103.99 - 1.04^(4.72 * x - 368.88)
# Mean Levels 3 - Fitted Parameters: [103.9853716    1.04031433   4.7235303  368.87744968]
# Mean Levels 4 - Formula: 208.10 - 1.05^(4.21 * x - 324.91)
# Mean Levels 4 - Fitted Parameters: [208.10020817   1.05211032   4.20763703 324.90807684]
# Mean Levels 5 - Formula: 368.29 - 1.05^(4.94 * x - 381.15)
# Mean Levels 5 - Fitted Parameters: [368.29129521   1.0498694    4.94378437 381.15423407]
# Mean Levels 1 - R-squared: 0.9537, MSE: 0.0638
# Mean Levels 2 - R-squared: 0.9763, MSE: 0.7142
# Mean Levels 3 - R-squared: 0.9907, MSE: 2.2245
# Mean Levels 4 - R-squared: 0.9932, MSE: 7.2145
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x_axis = np.linspace(1, 100, 100)

def curve_fit_level1(x):
    return 11.50 - 1.10**(1.21 * x - 106.02)

y_values = [curve_fit_level1(x) for x in x_axis]

plt.plot(x_axis, y_values, label='Curve Fit Level 1')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fit Level 1')

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_axis = np.linspace(1, 100, 100)

def curve_fit_level2(x):
    return 41.64 - 1.06**(3.07 * x - 251.51)

y_values = [curve_fit_level2(x) for x in x_axis]

plt.plot(x_axis, y_values, label='Curve Fit Level 2',color='yellow')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fit Level 2')

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_axis = np.linspace(1, 100, 100)

def curve_fit_level3(x):
    return 103.99 - 1.04**(4.72 * x - 368.88)

y_values = [curve_fit_level3(x) for x in x_axis]

plt.plot(x_axis, y_values, label='Curve Fit Level 3',color='pink')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fit Level 3')

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_axis = np.linspace(1, 100, 100)

def curve_fit_level4(x):
    return 208.10 - 1.05**(4.21 * x - 324.91)

y_values = [curve_fit_level4(x) for x in x_axis]

plt.plot(x_axis, y_values, label='Curve Fit Level 4',color='pink')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fit Level 4')

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_axis = np.linspace(1, 100, 100)

def curve_fit_level5(x):
    return 368.29 - 1.05**(4.94 * x - 381.15)

y_values = [curve_fit_level5(x) for x in x_axis]

plt.plot(x_axis, y_values, label='Curve Fit Level 5',color='black')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fit Level 5')

plt.legend()

plt.show()
