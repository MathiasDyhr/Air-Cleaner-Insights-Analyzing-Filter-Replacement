# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import dask.dataframe as dd
import numpy as np

# %%
DF_FanLevel = pd.read_csv('FanLevel.csv')
DF_FanLevel2 = pd.read_csv('FanLevel2023.csv')
DF_FanLevel_Full = pd.concat([DF_FanLevel, DF_FanLevel2], ignore_index=True)
DF_FanLevel_Full
# Out:
#           name                  time  activeauto        id  level  \
# 0     FanLevel  2022-07-29T03:43:27Z           0  6BE6E2E0      0
# 1     FanLevel  2022-07-29T03:43:36Z           0  6BE6E2E0      2
# 2     FanLevel  2022-07-29T03:43:40Z           0  6BE6E2E0      0
# 3     FanLevel  2022-07-29T04:00:31Z           0  6BE6E2E0      2
# 4     FanLevel  2022-07-29T04:00:49Z           0  6BE6E2E0      0
# ...        ...                   ...         ...       ...    ...
# 1834  FanLevel  2023-11-16T14:27:11Z           1  1F988330      4
# 1835  FanLevel  2023-11-16T14:27:18Z           1  1F988330      1
# 1836  FanLevel  2023-11-17T08:41:47Z           1  6BE6E2E0      4
# 1837  FanLevel  2023-11-17T10:07:21Z           1  6BE6E2E0      1
# 1838  FanLevel  2023-12-04T14:42:24Z           1  6BE6E2E0      2
#
#              name.1  profile
# 0     AirMaster2000        2
# 1     AirMaster2000        2
# 2     AirMaster2000        2
# 3     AirMaster2000        2
# ...

# %%
DF_InvSensor2022 = pd.read_csv('InvSensor2022.csv')
DF_InvSensor2023 = pd.read_csv('InvSensor2023_v2.csv')
DF_InvSensor_Full = pd.concat([DF_InvSensor2022, DF_InvSensor2023], ignore_index=True)
# Out:
# C:\Users\Mathi\AppData\Local\Temp\ipykernel_19584\3251824386.py:1: DtypeWarning: Columns (2,3,4,5,6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   DF_InvSensor2022 = pd.read_csv('InvSensor2022.csv')

# %%
DF_InvSensor_Full
# Out:
#               name                  time  ECO2   Hum  N0_3  N0_5 N10_0 N1_0  \
# 0        EnvSensor  2022-07-25T15:27:24Z   NaN  84.5  4698  1325    20  277
# 1        EnvSensor  2022-07-25T15:27:34Z   NaN  84.5  4623  1276    20  266
# 2        EnvSensor  2022-07-25T15:27:44Z   NaN  84.6  4503  1246    20  264
# 3        EnvSensor  2022-07-25T15:27:54Z   NaN  84.6  4617  1328    20  307
# 4        EnvSensor  2022-07-25T15:28:04Z   NaN  84.5  4584  1311    20  300
# ...            ...                   ...   ...   ...   ...   ...   ...  ...
# 6235197  EnvSensor  2023-12-26T23:37:19Z   855  57.1   246    77    20   23
# 6235198  EnvSensor  2023-12-26T23:37:29Z   847  57.1   234    76    20   27
# 6235199  EnvSensor  2023-12-26T23:37:39Z   856  57.3   234    78    20   29
# 6235200  EnvSensor  2023-12-26T23:37:49Z   850  57.3   228    73    20   25
# 6235201  EnvSensor  2023-12-26T23:37:53Z  1606  76.1  8883  2613    20  598
#
# ...

# %%
DF_FanLevel = pd.read_csv('FanLevel.csv')
DF_FanSpeedPower = pd.read_csv('FanSpeedPower.csv')
DF_InvSensor2022 = pd.read_csv('InvSensor2022.csv')
DF_InvSensor2023 = pd.read_csv('InvSensor2023.csv')
#combined_data = pd.concat([df[df['id'] == 'C16DE378'] for df in dataframes], axis=1)
#combined_data = combined_data.reset_index(drop=True)
# Out:
# C:\Users\Mathi\AppData\Local\Temp\ipykernel_14328\640404142.py:3: DtypeWarning: Columns (2,3,4,5,6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   DF_InvSensor2022 = pd.read_csv('InvSensor2022.csv')

# %%
DF_FanLevel
# Out:
#           name                  time  activeauto        id  level  \
# 0     FanLevel  2022-07-29T03:43:27Z           0  6BE6E2E0      0
# 1     FanLevel  2022-07-29T03:43:36Z           0  6BE6E2E0      2
# 2     FanLevel  2022-07-29T03:43:40Z           0  6BE6E2E0      0
# 3     FanLevel  2022-07-29T04:00:31Z           0  6BE6E2E0      2
# 4     FanLevel  2022-07-29T04:00:49Z           0  6BE6E2E0      0
# ...        ...                   ...         ...       ...    ...
# 1107  FanLevel  2023-08-28T13:15:45Z           1  6BE6E2E0      2
# 1108  FanLevel  2023-08-29T03:03:39Z           1  6BE6E2E0      4
# 1109  FanLevel  2023-08-29T07:39:39Z           1  6BE6E2E0      2
# 1110  FanLevel  2023-09-01T05:18:47Z           1  6BE6E2E0      4
# 1111  FanLevel  2023-09-01T09:29:33Z           1  6BE6E2E0      2
#
#              name.1  profile
# 0     AirMaster2000        2
# 1     AirMaster2000        2
# 2     AirMaster2000        2
# 3     AirMaster2000        2
# ...

# %%
DF_FanSpeedPower
# Out:
#                   name                  time        id         name.1  power  \
# 0        FanSpeedPower  2022-07-29T04:01:41Z  6BE6E2E0  AirMaster2000      0
# 1        FanSpeedPower  2022-07-29T04:01:46Z  6BE6E2E0  AirMaster2000     14
# 2        FanSpeedPower  2022-07-29T04:01:52Z  6BE6E2E0  AirMaster2000     38
# 3        FanSpeedPower  2022-07-29T04:01:57Z  6BE6E2E0  AirMaster2000     44
# 4        FanSpeedPower  2022-07-29T04:02:02Z  6BE6E2E0  AirMaster2000     44
# ...                ...                   ...       ...            ...    ...
# 3174950  FanSpeedPower  2023-09-02T08:47:05Z  1F988330            P88     46
# 3174951  FanSpeedPower  2023-09-02T08:47:07Z  6BE6E2E0            M88     12
# 3174952  FanSpeedPower  2023-09-02T08:47:10Z  1F988330            P88     47
# 3174953  FanSpeedPower  2023-09-02T08:47:12Z  6BE6E2E0            M88     10
# 3174954  FanSpeedPower  2023-09-02T08:47:17Z  6BE6E2E0            M88     11
#
#          speed_act  speed_set
# ...
